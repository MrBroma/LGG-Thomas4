# %% [markdown]
# ## Immoeliza project

# %% [markdown]
# ### Import of the necessary library

# %%
import pandas as pd
import numpy as np
import seaborn as sns

pd.options.display.max_colwidth=150

# %%
data = pd.read_json('final_dataset_to_clean.json')

# %%
data.shape
# Out:
# (118714, 32)

# %%
data.head()
# Out:
#                                                                                 Url  \
# 2   https://www.immoweb.be/en/classified/apartment/for-sale/zeebrugge/8380/10957010
# 6         https://www.immoweb.be/en/classified/house/for-sale/tournai/7500/10956841
# 8    https://www.immoweb.be/en/classified/house/for-sale/blankenberge/8370/10956807
# 10       https://www.immoweb.be/en/classified/house/for-sale/de-panne/8660/10956664
# 11    https://www.immoweb.be/en/classified/apartment/for-sale/hasselt/3500/10956668
#
#     BathroomCount  BedroomCount  ConstructionYear  Country District  \
# 2             1.0             1            1969.0  Belgium   Brugge
# 6             6.0            13            1920.0  Belgium  Tournai
# 8             2.0             4            2008.0  Belgium   Brugge
# 10            1.0             4               NaN  Belgium   Veurne
# 11            0.0             2            1972.0  Belgium  Hasselt
#
# ...

# %%
# Out:
#                                                                                                Url  \
# 181788                    https://www.immoweb.be/en/classified/house/for-sale/aalter/9880/11425357
# 181789                 https://www.immoweb.be/en/classified/house/for-sale/antwerpen/2020/11370107
# 181790             https://www.immoweb.be/en/classified/apartment/for-sale/antwerpen/2140/11485314
# 181791                https://www.immoweb.be/en/classified/apartment/for-sale/brugge/8000/11485038
# 181792  https://www.immoweb.be/en/classified/apartment/for-rent/woluwe-saint-lambert/1200/11370116
#
#         BathroomCount  BedroomCount  ConstructionYear  Country  District  \
# 181788            1.0             3            2024.0  Belgium      Gent
# 181789            4.0             4               NaN  Belgium   Antwerp
# 181790            1.0             2               NaN  Belgium   Antwerp
# 181791            1.0             2               NaN  Belgium    Brugge
# ...

# %%
data.groupby("TypeOfProperty")["Price"].agg([np.mean, np.median, np.max])
# Out:
# /tmp/ipykernel_11523/673286483.py:1: FutureWarning: The provided callable <function mean at 0x7fae5c463920> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.groupby("TypeOfProperty")["Price"].agg([np.mean, np.median, np.max])
# /tmp/ipykernel_11523/673286483.py:1: FutureWarning: The provided callable <function median at 0x7fae5c3a85e0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.groupby("TypeOfProperty")["Price"].agg([np.mean, np.median, np.max])
# ...

# %%
data.sort_values("NumberOfFacades", ascending=False)[["Url"]]
# Out:
#                                                                                                Url
# 60736              https://www.immoweb.be/en/classified/apartment/for-rent/bruxelles/1000/20010883
# 103993                  https://www.immoweb.be/en/classified/house/for-sale/gembloux/5030/11329216
# 721                     https://www.immoweb.be/en/classified/house/for-sale/arsimont/5060/10947037
# 41201              https://www.immoweb.be/en/classified/apartment/for-sale/antwerpen/2100/11460011
# 108517               https://www.immoweb.be/en/classified/house/for-sale/tielt-winge/3390/11294488
# ...                                                                                            ...
# 181728               https://www.immoweb.be/en/classified/apartment/for-sale/lebbeke/9280/10331313
# 181738  https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/10330761
# ...

# %%
data.columns.tolist()
# Out:
# ['Url',
#  'BathroomCount',
#  'BedroomCount',
#  'ConstructionYear',
#  'Country',
#  'District',
#  'Fireplace',
#  'FloodingZone',
#  'Furnished',
#  'Garden',
#  'GardenArea',
#  'Kitchen',
#  'LivingArea',
#  'Locality',
#  'MonthlyCharges',
#  'NumberOfFacades',
#  'PEB',
#  'PostalCode',
#  'Price',
#  'PropertyId',
#  'Province',
#  'Region',
#  'RoomCount',
#  'ShowerCount',
#  'StateOfBuilding',
#  'SubtypeOfProperty',
#  'SurfaceOfPlot',
#  'SwimmingPool',
#  'Terrace',
#  'ToiletCount',
#  'TypeOfProperty',
#  'TypeOfSale']

# %%
data['Openfire'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Openfire'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data['Openfire'].value_counts()
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115070 entries, 2 to 176905
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Url                115070 non-null  object
#  1   Openfire           115070 non-null  bool
#  2   Furnished          115070 non-null  bool
#  3   Terrace            115070 non-null  bool
#  4   Garden             115070 non-null  bool
#  5   PropertyId         115070 non-null  int64
#  6   TypeOfProperty     115070 non-null  int64
#  7   PostalCode         115070 non-null  int64
#  8   SubtypeOfProperty  115070 non-null  object
#  9   TypeOfSale         115070 non-null  int64
#  10  Price              115070 non-null  int64
#  11  Kitchen            64857 non-null   object
#  12  StateOfBuilding    78622 non-null   object
#  13  Heating            65283 non-null   object
#  14  Bedrooms           115070 non-null  int64
#  15  SurfaceOfGood      56247 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Url                      0
# Openfire                 0
# Furnished                0
# Terrace                  0
# Garden                   0
# PropertyId               0
# TypeOfProperty           0
# PostalCode               0
# SubtypeOfProperty        0
# TypeOfSale               0
# Price                    0
# Kitchen              50213
# StateOfBuilding      36448
# Heating              49787
# Bedrooms                 0
# SurfaceOfGood        58823
# SwimmingPool             0
# ConstructionYear     48399
# GardenArea           93446
# LivingArea           13693
# NumberOfFacades      40808
# dtype: int64

# %%
data.groupby(by =['TypeOfProperty', 'TypeOfSale']).size()
# Out:
# TypeOfProperty  TypeOfSale
# 1               1             47597
#                 2              2606
# 2               1             54882
#                 2              9985
# dtype: int64

# %%
data.nunique()
# Out:
# Url                  115070
# Openfire                  1
# Furnished                 2
# Terrace                   2
# Garden                    2
# PropertyId           115068
# TypeOfProperty            2
# PostalCode             1220
# SubtypeOfProperty        41
# TypeOfSale                2
# Price                 10295
# Kitchen                   8
# StateOfBuilding           6
# Heating                   7
# Bedrooms                 50
# SurfaceOfGood          4542
# SwimmingPool              2
# ConstructionYear        239
# GardenArea             1836
# LivingArea             1057
# NumberOfFacades          15
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Url                      0
# Openfire                 0
# Furnished                0
# Terrace                  0
# Garden                   0
# PropertyId               0
# TypeOfProperty           0
# PostalCode               0
# SubtypeOfProperty        0
# TypeOfSale               0
# Price                    0
# Kitchen              50213
# StateOfBuilding      36448
# Heating              49787
# Bedrooms                 0
# SurfaceOfGood        58823
# SwimmingPool             0
# ConstructionYear     48399
# GardenArea           93446
# LivingArea           13693
# NumberOfFacades      40808
# dtype: int64

# %%
for i in data.columns:
    null_rate = data[i].isnull().sum() / len(data) * 100
    if null_rate > 0:
        print(f"{i} null rate: %{null_rate:.2f}")
# Out:
# Kitchen null rate: %43.64
# StateOfBuilding null rate: %31.67
# Heating null rate: %43.27
# SurfaceOfGood null rate: %51.12
# ConstructionYear null rate: %42.06
# GardenArea null rate: %81.21
# LivingArea null rate: %11.90
# NumberOfFacades null rate: %35.46

# %%
data.sort_values("Kitchen")
# Out:
#                                                                                                Url  \
# 46031              https://www.immoweb.be/en/classified/apartment/for-rent/etterbeek/1040/11473810
# 117229                     https://www.immoweb.be/en/classified/house/for-sale/evere/1140/11187507
# 89416               https://www.immoweb.be/en/classified/apartment/for-sale/westerlo/2260/11309177
# 42070   https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/11469267
# 117240                 https://www.immoweb.be/en/classified/house/for-sale/blaasveld/2830/11187388
# ...                                                                                            ...
# 176735               https://www.immoweb.be/en/classified/apartment/for-sale/deerlijk/8540/8756251
# 176760            https://www.immoweb.be/en/classified/apartment/for-sale/trois-ponts/4980/8749786
# ...

# %%
data[data["PostalCode"] == False]
# Out:
#                                                                                          Url  \
# 28711          https://www.immoweb.be/en/classified/house/for-sale/perla-bonita/0000/7437738
# 28712                https://www.immoweb.be/en/classified/house/for-sale/ceiba/00000/7437739
# 28715         https://www.immoweb.be/en/classified/house/for-sale/rio-san-juan/00000/7437737
# 91572                https://www.immoweb.be/en/classified/apartment/for-rent/gent/0/11297796
# 102555  https://www.immoweb.be/en/classified/apartment/for-sale/al-mina-al-siyahi/0/11321866
# 165487         https://www.immoweb.be/en/classified/apartment/for-sale/leuven/00000/10046544
#
#         Openfire  Furnished  Terrace  Garden  PropertyId  TypeOfProperty  \
# 28711      False      False     True   False     7437738               1
# 28712      False      False     True   False     7437739               1
# 28715      False      False    False   False     7437737               1
# ...

# %% [markdown]
# ### Drop property with PostalCode False (0) 4 properties outside belgium and 2 properties in Belgium without infos

# %%
# data = data[data["PostalCode"] == True]

# %%
data
# Out:
#                                                                                       Url  \
# 2              https://www.immoweb.be/en/classified/house/for-sale/steendorp/9140/8720603
# 6            https://www.immoweb.be/en/classified/apartment/for-rent/ixelles/1050/8719883
# 8                  https://www.immoweb.be/en/classified/house/for-sale/reet/2840/10760048
# 10               https://www.immoweb.be/en/classified/house/for-sale/bilzen/3740/10759911
# 13            https://www.immoweb.be/en/classified/house/for-sale/koolskamp/8851/10759812
# ...                                                                                   ...
# 176860  https://www.immoweb.be/en/classified/apartment/for-sale/sint-truiden/3800/8727283
# 176890        https://www.immoweb.be/en/classified/apartment/for-rent/virton/6760/8724542
# 176903    https://www.immoweb.be/en/classified/apartment/for-sale/herentals/2200/20014272
# ...

# %%
# postal code in Belgium
postal_code = pd.read_excel("zipcodes_num_fr_new.xls")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniforge3/envs/myenv/lib/python3.11/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~/miniforge3/envs/myenv/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ...
